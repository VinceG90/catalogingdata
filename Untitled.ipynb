# %%
# hello

# %%
welcome to my slideshow
# Out:
#   File "<ipython-input-2-a4f5e2bc93d3>", line 1
#     welcome to my slideshow
#              ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
jupyter nbconvert Untitled.ipynb --to slides --post serve
# Out:
#   File "<ipython-input-4-d7c91dc9163d>", line 1
#     jupyter nbconvert Untitled.ipynb --to slides --post serve
#                     ^
# SyntaxError: invalid syntax

# %%
pd.read_csv('Nutting Library Item Acquisition Form (Responses) - Pending!.csv')
# Out:
#                   excel             Email Address  \
# 0     8/9/2019 15:46:55          ann.dyer@mma.edu
# 1                8/9/19    lauren.gargani@mma.edu
# 2                8/9/19    lauren.gargani@mma.edu
# 3                8/9/19    lauren.gargani@mma.edu
# 4                8/9/19    lauren.gargani@mma.edu
# 5                8/9/19    lauren.gargani@mma.edu
# 6                8/9/19    lauren.gargani@mma.edu
# 7                8/9/19    lauren.gargani@mma.edu
# 8                8/9/19    lauren.gargani@mma.edu
# 9                8/9/19    lauren.gargani@mma.edu
# 10               8/9/19    lauren.gargani@mma.edu
# 11               8/9/19    lauren.gargani@mma.edu
# 12                  NaN                       NaN
# 13               8/9/19    lauren.gargani@mma.edu
# 14    8/2/2019 14:17:26    lauren.gargani@mma.edu
# 15    8/2/2019 13:28:33    lauren.gargani@mma.edu
# 16    8/2/2019 13:26:59    lauren.gargani@mma.edu
# 17     8/2/2019 9:32:08    lauren.gargani@mma.edu
# ...
